# %% [markdown]
# ## Open API(Rest API) 활용
#
# ### Open API(Rest API)란?
#  - **API:** Application Programming Interface의 약자로, 특정 프로그램을 만들기 위해 제공되는 모듈(함수 등)을 의미
#  - **Open API:** 공개 API라고도 불리우며, 누구나 사용할 수 있도록 공개된 API (주로 Rest API 기술을 많이 사용함)
#  - **Rest API:** Representational State Transfer API의 약자로, HTTP프로토콜을 통해 서버 제공 기능을 사용할 수 있는 함수를 의미
#    - 일반적으로 XML, JSON의 형태로 응답을 전달(원하는 데이터 추출이 수월)
#    - [참고 - RestAPI란](http://hyunalee.tistory.com/1)

# %% [markdown]
# ### 네이버 검색 Open API를 이용한 크롤링 초간단 실습
#  - https://developers.naver.com/main/
#  - [쇼핑 검색 가이드 문서](https://developers.naver.com/docs/serviceapi/search/shopping/shopping.md#%EC%87%BC%ED%95%91)
#    - 네이버 Open API 이용신청 [참고](http://hnark.tistory.com/135)

# %% [markdown]
# - postma 사용법
#    1. Sign Up in Postman
#    2. Insert https://openapi.naver.com/v1/search/news.json?query=스마트 into GET
#    3. Add X-Naver-Client-Id(key), <font color="blue">아이디</font>(value) into Headers
#    4. Add X-Naver-Client-Secret(key), <font color="blue">비번</font>(value) into Headers
#    5. Send
#    <img src="naver_shopping.png" />

# %% [markdown]
# ```
# {
#     "lastBuildDate": "Sun, 26 Dec 2021 17:28:26 +0900",
#     "total": 1245379,
#     "start": 1,
#     "display": 10,
#     "items": [
#         {
#             "title": "Apple <b>에어팟</b> 3세대 2021년형 (MME73KH/A)",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=29413009627",
#             "image": "https://shopping-phinf.pstatic.net/main_2941300/29413009627.20211028160140.jpg",
#             "lprice": "208900",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "29413009627",
#             "productType": "1",
#             "brand": "Apple",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 2세대 유선충전 모델 (MV7N2KH/A)",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=18622086330",
#             "image": "https://shopping-phinf.pstatic.net/main_1862208/18622086330.20200831140839.jpg",
#             "lprice": "139900",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "18622086330",
#             "productType": "1",
#             "brand": "에어팟",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 프로 2021년형 맥세이프 호환 (MLWK3KH/A)",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=29412453621",
#             "image": "https://shopping-phinf.pstatic.net/main_2941245/29412453621.20211028154519.jpg",
#             "lprice": "255000",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "29412453621",
#             "productType": "1",
#             "brand": "Apple",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 3세대",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=29923300618",
#             "image": "https://shopping-phinf.pstatic.net/main_2992330/29923300618.20211202151514.jpg",
#             "lprice": "124940",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "29923300618",
#             "productType": "1",
#             "brand": "Apple",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 프로 2019년형 맥세이프 미호환 (MWP22KH/A)",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=21192710714",
#             "image": "https://shopping-phinf.pstatic.net/main_2119271/21192710714.20200831140731.jpg",
#             "lprice": "245900",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "21192710714",
#             "productType": "1",
#             "brand": "에어팟",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 2세대 무선충전 모델 (MRXJ2KH/A)",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=18754856889",
#             "image": "https://shopping-phinf.pstatic.net/main_1875485/18754856889.20200831140938.jpg",
#             "lprice": "143900",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "18754856889",
#             "productType": "1",
#             "brand": "에어팟",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 프로 3세대 MLWK3AM/A",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=29709676621",
#             "image": "https://shopping-phinf.pstatic.net/main_2970967/29709676621.20211116111731.jpg",
#             "lprice": "199000",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "29709676621",
#             "productType": "1",
#             "brand": "에어팟",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 프로",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=27424294522",
#             "image": "https://shopping-phinf.pstatic.net/main_2742429/27424294522.20210603143608.jpg",
#             "lprice": "237450",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "27424294522",
#             "productType": "1",
#             "brand": "Apple",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "<b>에어팟</b> 한쪽 <b>에어팟</b>프로 왼쪽 오른쪽 유닛 단품 본체 <b>에어팟</b> 2세대 1세대 충전케이스",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=82398210877",
#             "image": "https://shopping-phinf.pstatic.net/main_8239821/82398210877.961.jpg",
#             "lprice": "54000",
#             "hprice": "",
#             "mallName": "사라구 saragoo",
#             "productId": "82398210877",
#             "productType": "2",
#             "brand": "Apple",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         },
#         {
#             "title": "Apple <b>에어팟</b> 1세대 (MMEF2KH/A)",
#             "link": "https://search.shopping.naver.com/gate.nhn?id=10776906666",
#             "image": "https://shopping-phinf.pstatic.net/main_1077690/10776906666.20211111161139.jpg",
#             "lprice": "166890",
#             "hprice": "",
#             "mallName": "네이버",
#             "productId": "10776906666",
#             "productType": "1",
#             "brand": "Apple",
#             "maker": "Apple",
#             "category1": "디지털/가전",
#             "category2": "음향가전",
#             "category3": "블루투스셋",
#             "category4": "블루투스이어폰/이어셋"
#         }
#     ]
# }
# ```

# %%
import requests

client_id = '아이디'
client_secrest= '비번'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=에어팟'
header_params = {"X-Naver-Client-id":client_id, "X-Naver-Client-Secret":client_secrest}
res = requests.get(naver_open_api, headers=header_params)

# print(res.text)

if res.status_code == 200:
    data = res.json()
    print(data['items'][0]['title'])
else:
    print("Error Code:",res.status_code)

# data = res.json()
# print(data['items'][0]['title'])
# Out:
# Apple <b>에어팟</b> 3세대 2021년형 (MME73KH/A)

# %%
import requests
import pprint

client_id = '아이디'
client_secrest= '비번'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=에어팟'
header_params = {"X-Naver-Client-id":client_id, "X-Naver-Client-Secret":client_secrest}
res = requests.get(naver_open_api, headers=header_params)


if res.status_code == 200:
    data = res.json()
    pprint.pprint(data)
else:
    print("Error Code:",res.status_code)
# Out:
# {'display': 10,
#  'items': [{'brand': 'Apple',
#             'category1': '디지털/가전',
#             'category2': '음향가전',
#             'category3': '블루투스셋',
#             'category4': '블루투스이어폰/이어셋',
#             'hprice': '',
#             'image': 'https://shopping-phinf.pstatic.net/main_2941300/29413009627.20211028160140.jpg',
#             'link': 'https://search.shopping.naver.com/gate.nhn?id=29413009627',
#             'lprice': '208900',
#             'maker': 'Apple',
#             'mallName': '네이버',
#             'productId': '29413009627',
#             'productType': '1',
#             'title': 'Apple <b>에어팟</b> 3세대 2021년형 (MME73KH/A)'},
#            {'brand': '에어팟',
#             'category1': '디지털/가전',
#             'category2': '음향가전',
#             'category3': '블루투스셋',
#             'category4': '블루투스이어폰/이어셋',
#             'hprice': '',
#             'image': 'https://shopping-phinf.pstatic.net/main_1862208/18622086330.20200831140839.jpg',
# ...

# %%
import requests
import pprint

client_id = '아이디'
client_secrest= '비번'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=에어팟'
header_params = {"X-Naver-Client-id":client_id, "X-Naver-Client-Secret":client_secrest}
res = requests.get(naver_open_api, headers=header_params)


if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']): # index enumerate 앞에 숫자를 붙혀준다
        print(index+1, item['title'], item['link'])
else:
    print("Error Code:",res.status_code)
# Out:
# 1 Apple <b>에어팟</b> 3세대 2021년형 (MME73KH/A) https://search.shopping.naver.com/gate.nhn?id=29413009627
# 2 Apple <b>에어팟</b> 2세대 유선충전 모델 (MV7N2KH/A) https://search.shopping.naver.com/gate.nhn?id=18622086330
# 3 Apple <b>에어팟</b> 프로 2021년형 맥세이프 호환 (MLWK3KH/A) https://search.shopping.naver.com/gate.nhn?id=29412453621
# 4 Apple <b>에어팟</b> 3세대 https://search.shopping.naver.com/gate.nhn?id=29923300618
# 5 Apple <b>에어팟</b> 프로 2019년형 맥세이프 미호환 (MWP22KH/A) https://search.shopping.naver.com/gate.nhn?id=21192710714
# 6 Apple <b>에어팟</b> 2세대 무선충전 모델 (MRXJ2KH/A) https://search.shopping.naver.com/gate.nhn?id=18754856889
# 7 Apple <b>에어팟</b> 프로 3세대 MLWK3AM/A https://search.shopping.naver.com/gate.nhn?id=29709676621
# 8 Apple <b>에어팟</b> 프로 https://search.shopping.naver.com/gate.nhn?id=27424294522
# 9 <b>에어팟</b> 한쪽 <b>에어팟</b>프로 왼쪽 오른쪽 유닛 단품 본체 <b>에어팟</b> 2세대 1세대 충전케이스 https://search.shopping.naver.com/gate.nhn?id=82398210877
# ...
